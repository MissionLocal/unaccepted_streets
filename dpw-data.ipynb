# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### setup

# %% [markdown]
# Reading in the data file provided by the Department of Public Works on July 10, 2025. This dataset includes all unaccepted streets.

# %%
df_dpw = pd.read_csv('./data/dpw_data.csv')

# %%
df_dpw.columns = df_dpw.columns.str.lower().str.replace(' ', '_')

# %%
df_dpw
# Out:
#            cnn    street_name  \
# 0       110000        01ST ST
# 1       114000        01ST ST
# 2       140000        02ND ST
# 3       150000       03RD AVE
# 4       159000       03RD AVE
# ...        ...            ...
# 1945  15329000  SUNNYDALE AVE
# 1946  15331000    SUNRISE WAY
# 1947  14348000       MACKY LN
# 1948  14291000     MAYBECK ST
# 1949  14276000    FARALLON ST
#
#                                                location      x_coord  \
# 0       01ST ST: CLEMENTINA ST to FOLSOM ST (245 - 299)  6014174.520
# 1     01ST ST: HARRISON ST \ I-80 E ON RAMP to END (...  6014784.513
# 2       02ND ST: HARRISON ST to STILLMAN ST (400 - 459)  6014173.689
# 3                     03RD AVE: END to LAKE ST (1 - 99)  5994888.446
# 4     03RD AVE: KEZAR DR \ LINCOLN WAY to LINCOLN WA...  5995166.956
# ...                                                 ...          ...
# 1945            SUNNYDALE AVE: SANTOS ST to END (0 - 0)  6006743.014
# 1946        SUNRISE WAY: MALOSI ST to SANTOS ST (0 - 0)  6006690.422
# 1947           MACKY LN: GOLDEN BELL WAY to END (0 - 0)  6021870.888
# 1948  MAYBECK ST: AVENUE OF THE PALMS to GARDEN WALK...  6019867.686
# 1949       FARALLON ST: END to BRAGHETTA LN (248 - 299)  6021832.966
#
#           y_coord   latitude   longitude bos_district zip_code  \
# 0     2114753.853  37.787508 -122.394745            6    94105
# 1     2114116.436  37.785792 -122.392589            6    94105
# 2     2113442.524  37.783907 -122.394656            6    94107
# 3     2114976.446  37.787028 -122.461486            1    94118
# 4     2107405.925  37.766257 -122.459974            7    94117
# ...           ...        ...         ...          ...      ...
# 1945  2087633.962  37.712627 -122.418532
# 1946  2086843.851  37.710454 -122.418658
# 1947  2127869.609  37.823946 -122.369023
# 1948  2128150.234  37.824606 -122.375976
# 1949  2126919.408  37.821335 -122.369088
#
#      sfar_neighborhood_desc  jurisdiction    layer bike_path accepted
# 0               South Beach  CALTRANS/DPW  STREETS        No        N
# 1               South Beach  CALTRANS/DPW  STREETS        No        N
# 2           South of Market  CALTRANS/DPW  STREETS       Yes        N
# 3                      Lake           DPW  STREETS        No        N
# 4              Inner Sunset           DPW  STREETS       Yes        N
# ...                     ...           ...      ...       ...      ...
# 1945                                  DPW    PAPER        No        N
# 1946                                  DPW    PAPER        No        N
# 1947                                  DPW  STREETS        No        N
# 1948                                  DPW  STREETS        No        N
# 1949                                  DPW  STREETS        No        N
#
# [1950 rows x 14 columns]

# %% [markdown]
# reading in a dataset that contains **all** streets in San Francisco. This data was downloaded from [S.F. Open Data](https://data.sfgov.org/Geographic-Locations-and-Boundaries/Streets-Active-and-Retired/3psu-pn9h/about_data) on July 10, 2025.

# %%
df_streets = pd.read_csv('./data/Streets___Active_and_Retired_20250709.csv')

# %%
df_streets.head()
# Out:
#         cnn  lf_fadd  lf_toadd  rt_fadd  rt_toadd  street st_type        f_st  \
# 0   9999000    301.0     399.0    300.0     398.0  ORTEGA      ST    10TH AVE
# 1  10000202    501.0     599.0      0.0       0.0  ORTEGA      ST  AERIAL WAY
# 2  10002000    801.0     899.0    800.0     898.0  ORTEGA      ST    15TH AVE
# 3  10010000   1501.0    1599.0   1500.0    1598.0  ORTEGA      ST    22ND AVE
# 4  10019000   2401.0    2499.0   2400.0    2498.0  ORTEGA      ST    31ST AVE
#
#            t_st  f_node_cnn  t_node_cnn  accepted  active  classcode  \
# 0      11TH AVE  27098000.0  27113000.0      True    True        5.0
# 1  CASCADE WALK  32870000.0  32871000.0      True    True        5.0
# 2      16TH AVE  27308000.0  27310000.0      True    True        5.0
# 3      23RD AVE  27338000.0  27379000.0      True    True        5.0
# 4      32ND AVE  27674000.0  27677000.0      True    True        5.0
#
#    date_added date_altered date_dropped gds_chg_id_add gds_chg_id_altered  \
# 0  07/01/1998          NaN          NaN            NaN                NaN
# 1  07/01/1998   08/14/2013          NaN            NaN           2013-028
# 2  07/01/1998          NaN          NaN            NaN                NaN
# 3  07/01/1998          NaN          NaN            NaN                NaN
# 4  07/01/1998          NaN          NaN            NaN                NaN
#
#   gds_chg_id_dropped jurisdiction    layer                nhood oneway  \
# 0                NaN          DPW  STREETS  Golden Gate Heights      B
# 1                NaN          DPW  STREETS  Golden Gate Heights      T
# 2                NaN          DPW  STREETS         Inner Sunset      B
# 3                NaN          DPW  STREETS       Central Sunset      B
# 4                NaN          DPW  STREETS       Central Sunset      B
#
#   street_gc streetname streetname_gc  zip_code analysis_neighborhood  \
# 0    ORTEGA  ORTEGA ST     ORTEGA ST   94122.0          Inner Sunset
# 1    ORTEGA  ORTEGA ST     ORTEGA ST   94122.0          Inner Sunset
# 2    ORTEGA  ORTEGA ST     ORTEGA ST   94122.0          Inner Sunset
# 3    ORTEGA  ORTEGA ST     ORTEGA ST   94122.0       Sunset/Parkside
# 4    ORTEGA  ORTEGA ST     ORTEGA ST   94122.0       Sunset/Parkside
#
#    supervisor_district                                               line  \
# 0                  7.0  LINESTRING (-122.466600499 37.752803078, -122....
# 1                  7.0  LINESTRING (-122.468335072 37.753243731, -122....
# 2                  7.0  LINESTRING (-122.472007575 37.752569818, -122....
# 3                  4.0  LINESTRING (-122.479557564 37.752234616, -122....
# 4                  4.0  LINESTRING (-122.489193569 37.751806869, -122....
#
#                data_as_of          data_loaded_at
# 0  2025/07/09 03:46:00 AM  2025/07/09 10:11:28 AM
# 1  2025/07/09 03:46:00 AM  2025/07/09 10:11:28 AM
# 2  2025/07/09 03:46:00 AM  2025/07/09 10:11:28 AM
# 3  2025/07/09 03:46:00 AM  2025/07/09 10:11:28 AM
# 4  2025/07/09 03:46:00 AM  2025/07/09 10:11:28 AM

# %% [markdown]
# Let's keep the following columns:

# %%
df_streets = df_streets[['line', 'cnn', 'active', 'supervisor_district']]

# %%
df_streets
# Out:
#                                                     line       cnn  active  \
# 0      LINESTRING (-122.466600499 37.752803078, -122....   9999000    True
# 1      LINESTRING (-122.468335072 37.753243731, -122....  10000202    True
# 2      LINESTRING (-122.472007575 37.752569818, -122....  10002000    True
# 3      LINESTRING (-122.479557564 37.752234616, -122....  10010000    True
# 4      LINESTRING (-122.489193569 37.751806869, -122....  10019000    True
# ...                                                  ...       ...     ...
# 17150  LINESTRING (-122.389022427 37.775404055, -122....  15287000    True
# 17151  LINESTRING (-122.373499523 37.734495279, -122....   6535000    True
# 17152  LINESTRING (-122.423353436 37.709250951, -122....   6150201    True
# 17153  LINESTRING (-122.378784033 37.712929869, -122....   6179000    True
# 17154  LINESTRING (-122.374647925 37.73634196, -122.3...   6785000    True
#
#        supervisor_district
# 0                      7.0
# 1                      7.0
# 2                      7.0
# 3                      4.0
# 4                      4.0
# ...                    ...
# 17150                  6.0
# 17151                  NaN
# 17152                  NaN
# 17153                  NaN
# 17154                  NaN
#
# [17155 rows x 4 columns]

# %% [markdown]
# Since the data from DPW does not include a geometry column with line segments, we're going to use the geometry column from the streets dataset. We'll merge the two datasets on the "CNN" column, which is the unique identifier for each street segment.

# %%
df_dpw = df_dpw.merge(df_streets, on='cnn', how='left')

# %%
df_dpw
# Out:
#            cnn    street_name  \
# 0       110000        01ST ST
# 1       114000        01ST ST
# 2       140000        02ND ST
# 3       150000       03RD AVE
# 4       159000       03RD AVE
# ...        ...            ...
# 1945  15329000  SUNNYDALE AVE
# 1946  15331000    SUNRISE WAY
# 1947  14348000       MACKY LN
# 1948  14291000     MAYBECK ST
# 1949  14276000    FARALLON ST
#
#                                                location      x_coord  \
# 0       01ST ST: CLEMENTINA ST to FOLSOM ST (245 - 299)  6014174.520
# 1     01ST ST: HARRISON ST \ I-80 E ON RAMP to END (...  6014784.513
# 2       02ND ST: HARRISON ST to STILLMAN ST (400 - 459)  6014173.689
# 3                     03RD AVE: END to LAKE ST (1 - 99)  5994888.446
# 4     03RD AVE: KEZAR DR \ LINCOLN WAY to LINCOLN WA...  5995166.956
# ...                                                 ...          ...
# 1945            SUNNYDALE AVE: SANTOS ST to END (0 - 0)  6006743.014
# 1946        SUNRISE WAY: MALOSI ST to SANTOS ST (0 - 0)  6006690.422
# 1947           MACKY LN: GOLDEN BELL WAY to END (0 - 0)  6021870.888
# 1948  MAYBECK ST: AVENUE OF THE PALMS to GARDEN WALK...  6019867.686
# 1949       FARALLON ST: END to BRAGHETTA LN (248 - 299)  6021832.966
#
#           y_coord   latitude   longitude bos_district zip_code  \
# 0     2114753.853  37.787508 -122.394745            6    94105
# 1     2114116.436  37.785792 -122.392589            6    94105
# 2     2113442.524  37.783907 -122.394656            6    94107
# 3     2114976.446  37.787028 -122.461486            1    94118
# 4     2107405.925  37.766257 -122.459974            7    94117
# ...           ...        ...         ...          ...      ...
# 1945  2087633.962  37.712627 -122.418532
# 1946  2086843.851  37.710454 -122.418658
# 1947  2127869.609  37.823946 -122.369023
# 1948  2128150.234  37.824606 -122.375976
# 1949  2126919.408  37.821335 -122.369088
#
#      sfar_neighborhood_desc  jurisdiction    layer bike_path accepted  \
# 0               South Beach  CALTRANS/DPW  STREETS        No        N
# 1               South Beach  CALTRANS/DPW  STREETS        No        N
# 2           South of Market  CALTRANS/DPW  STREETS       Yes        N
# 3                      Lake           DPW  STREETS        No        N
# 4              Inner Sunset           DPW  STREETS       Yes        N
# ...                     ...           ...      ...       ...      ...
# 1945                                  DPW    PAPER        No        N
# 1946                                  DPW    PAPER        No        N
# 1947                                  DPW  STREETS        No        N
# 1948                                  DPW  STREETS        No        N
# 1949                                  DPW  STREETS        No        N
#
#                                                    line active  \
# 0     LINESTRING (-122.395007842 37.787717615, -122....   True
# 1     LINESTRING (-122.392936685 37.786067532, -122....   True
# 2     LINESTRING (-122.395160622 37.784311013, -122....   True
# 3     LINESTRING (-122.461501479 37.787239798, -122....   True
# 4     LINESTRING (-122.459931488 37.76634884, -122.4...   True
# ...                                                 ...    ...
# 1945  LINESTRING (-122.418038222 37.712487948, -122....   True
# 1946  LINESTRING (-122.418243703 37.710337536, -122....   True
# 1947  LINESTRING (-122.368222763 37.822730801, -122....   True
# 1948  LINESTRING (-122.376249932 37.824351379, -122....   True
# 1949  LINESTRING (-122.369332765 37.821233243, -122....   True
#
#       supervisor_district
# 0                     6.0
# 1                     6.0
# 2                     6.0
# 3                     1.0
# 4                     7.0
# ...                   ...
# 1945                 10.0
# 1946                 10.0
# 1947                  6.0
# 1948                  6.0
# 1949                  6.0
#
# [1950 rows x 17 columns]

# %% [markdown]
# Out of the 1938 unaccepted streets, the following did not match a street segment in the streets dataset.

# %%
df_dpw[df_dpw['line'].isna()]
# Out:
#            cnn         street_name  \
# 1440  10830002                 NaN
# 1843  15320000  TREASURE ISLAND RD
# 1848  15336000        CHUMASERO DR
# 1849  15337000        CHUMASERO DR
# 1852  15308000          MACALLA RD
# 1853  15309000  TREASURE ISLAND RD
# 1854  15310000  TREASURE ISLAND RD
# 1855  15311000  TREASURE ISLAND RD
# 1856  15312000  TREASURE ISLAND RD
# 1857  15314000       NORTH GATE RD
# 1858  15315000       NORTH GATE RD
# 1918  14271000           BRUTON ST
#
#                                                location      x_coord  \
# 1440                                                NaN          NaN
# 1843  TREASURE ISLAND RD: I-80 E OFF RAMP \ I-80 W O...  6022434.789
# 1848             CHUMASERO DR: END to FONT BLVD (0 - 0)  5991141.029
# 1849             CHUMASERO DR: FONT BLVD to END (0 - 0)  5990846.290
# 1852  MACALLA RD: END to I-80 W ON RAMP \ NORTH GATE...  6023218.504
# 1853         TREASURE ISLAND RD: END to END (670 - 699)  6023361.507
# 1854         TREASURE ISLAND RD: END to END (700 - 750)  6023385.570
# 1855         TREASURE ISLAND RD: END to END (701 - 751)  6023285.543
# 1856  TREASURE ISLAND RD: END to I-80 W ON RAMP \ MA...  6023377.543
# 1857  NORTH GATE RD: I-80 W ON RAMP \ MACALLA RD \ S...  6022933.843
# 1858  NORTH GATE RD: GARDEN WAY \ WHITING WAY to END...  6023078.880
# 1918             BRUTON ST: END to GARDEN WALK (1 - 49)  6020865.457
#
#           y_coord   latitude   longitude bos_district zip_code  \
# 1440          NaN        NaN         NaN           10    94124
# 1843  2122471.247  37.809154 -122.366698
# 1848  2088883.846  37.715168 -122.472548
# 1849  2088551.182  37.714238 -122.473543
# 1852  2123420.124  37.811802 -122.364051
# 1853  2122512.999  37.809319 -122.363494
# 1854  2122990.119  37.810631 -122.363443
# 1855  2122842.413  37.810220 -122.363779
# 1856  2123201.128  37.811210 -122.363485
# 1857  2123626.965  37.812355 -122.365050
# 1858  2123990.253  37.813360 -122.364574
# 1918  2125888.804  37.818452 -122.372366
#
#      sfar_neighborhood_desc jurisdiction       layer bike_path accepted line  \
# 1440       Bayview District          DPW         NaN        No        N  NaN
# 1843                                 DPW     STREETS        No        N  NaN
# 1848                                 DPW       PAPER        No        N  NaN
# 1849                                 DPW       PAPER        No        N  NaN
# 1852                                 DPW     STREETS        No        N  NaN
# 1853                                 DPW     STREETS        No        N  NaN
# 1854                                 DPW     STREETS        No        N  NaN
# 1855                                 DPW     STREETS        No        N  NaN
# 1856                                 DPW     STREETS        No        N  NaN
# 1857                                 DPW     STREETS        No        N  NaN
# 1858                                 DPW     STREETS        No        N  NaN
# 1918                                 DPW  streets_ti        No        N  NaN
#
#      active  supervisor_district
# 1440    NaN                  NaN
# 1843    NaN                  NaN
# 1848    NaN                  NaN
# 1849    NaN                  NaN
# 1852    NaN                  NaN
# 1853    NaN                  NaN
# 1854    NaN                  NaN
# 1855    NaN                  NaN
# 1856    NaN                  NaN
# 1857    NaN                  NaN
# 1858    NaN                  NaN
# 1918    NaN                  NaN

# %% [markdown]
# We can't analyze these streets, so we'll remove them from the unaccepted streets dataset:

# %%
df_dpw = df_dpw.dropna(subset=['line'])

# %% [markdown]
# Below we're converting the unaccepted streets dataset to a GeoDataFrame, which allows us to work with the geometry column.

# %%
df_dpw["geometry"] = df_dpw["line"].apply(wkt.loads)

gdf = gpd.GeoDataFrame(df_dpw, geometry="geometry")
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_10698/3428783731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dpw["geometry"] = df_dpw["line"].apply(wkt.loads)

# %%
gdf.head()
# Out:
#       cnn street_name                                           location  \
# 0  110000     01ST ST    01ST ST: CLEMENTINA ST to FOLSOM ST (245 - 299)
# 1  114000     01ST ST  01ST ST: HARRISON ST \ I-80 E ON RAMP to END (...
# 2  140000     02ND ST    02ND ST: HARRISON ST to STILLMAN ST (400 - 459)
# 3  150000    03RD AVE                  03RD AVE: END to LAKE ST (1 - 99)
# 4  159000    03RD AVE  03RD AVE: KEZAR DR \ LINCOLN WAY to LINCOLN WA...
#
#        x_coord      y_coord   latitude   longitude bos_district zip_code  \
# 0  6014174.520  2114753.853  37.787508 -122.394745            6    94105
# 1  6014784.513  2114116.436  37.785792 -122.392589            6    94105
# 2  6014173.689  2113442.524  37.783907 -122.394656            6    94107
# 3  5994888.446  2114976.446  37.787028 -122.461486            1    94118
# 4  5995166.956  2107405.925  37.766257 -122.459974            7    94117
#
#   sfar_neighborhood_desc  jurisdiction    layer bike_path accepted  \
# 0            South Beach  CALTRANS/DPW  STREETS        No        N
# 1            South Beach  CALTRANS/DPW  STREETS        No        N
# 2        South of Market  CALTRANS/DPW  STREETS       Yes        N
# 3                   Lake           DPW  STREETS        No        N
# 4           Inner Sunset           DPW  STREETS       Yes        N
#
#                                                 line active  \
# 0  LINESTRING (-122.395007842 37.787717615, -122....   True
# 1  LINESTRING (-122.392936685 37.786067532, -122....   True
# 2  LINESTRING (-122.395160622 37.784311013, -122....   True
# 3  LINESTRING (-122.461501479 37.787239798, -122....   True
# 4  LINESTRING (-122.459931488 37.76634884, -122.4...   True
#
#    supervisor_district                                           geometry
# 0                  6.0  LINESTRING (-122.39501 37.78772, -122.39448 37...
# 1                  6.0  LINESTRING (-122.39294 37.78607, -122.39224 37...
# 2                  6.0  LINESTRING (-122.39516 37.78431, -122.39415 37...
# 3                  1.0  LINESTRING (-122.46150 37.78724, -122.46147 37...
# 4                  7.0  LINESTRING (-122.45993 37.76635, -122.46002 37...

# %% [markdown]
# ### calculting the length of each unaccepted street

# %% [markdown]
# Below I am assigning a CRS to the unaccepted streets dataset. The CRS is set to EPSG:4326, which is a common coordinate system. However, its measurements are in degrees and not in meters, so I need to convert it to a projected CRS that uses meters (32610). Once converted we can add a length column.

# %%
gdf = gdf.set_crs("EPSG:4326")

gdf = gdf.to_crs("EPSG:32610")

gdf["length_m"] = gdf.geometry.length

# %%
print(gdf.crs)
# Out:
# EPSG:32610

# %% [markdown]
# Checking that the measuremnts look correct:

# %%
gdf.length_m.value_counts()
# Out:
# 65.689769     1
# 49.668933     1
# 90.481978     1
# 69.028951     1
# 193.342833    1
#              ..
# 52.593511     1
# 51.446495     1
# 211.393192    1
# 113.413481    1
# 48.561061     1
# Name: length_m, Length: 1938, dtype: int64

# %%
gdf.length_m.sum()
# Out:
# 220431.27980877284

# %%
gdf["length_m"].mean()
# Out:
# 113.7416304482832

# %% [markdown]
# Below I am comparing two columns for the supervisor district, for some reason, the one from the streets data seems to capture more than the one from the DPW dataset, which includes blanks. The blanks in the streets one come from areas in water or just outside the city's / a district's jurisdiction. To capture the most street segments we'll use the one from the streets dataset.

# %%
total_length_by_district = gdf.groupby('bos_district')['length_m'].sum().reset_index()

# %%
total_length_by_district_2 = gdf.groupby('supervisor_district')['length_m'].sum().reset_index()

# %%
total_length_by_district
# Out:
#    bos_district      length_m
# 0                34079.470582
# 1             1   6795.323660
# 2            10  51250.132509
# 3            11  17849.209816
# 4             2   4765.697315
# 5             3   9336.740797
# 6             4   2856.955789
# 7             5   3396.525195
# 8             6  20377.139817
# 9             7  29424.070933
# 10            8  15974.627602
# 11            9  24325.385794

# %%
total_length_by_district_2
# Out:
#     supervisor_district      length_m
# 0                   1.0   6795.323660
# 1                   2.0  10848.119709
# 2                   3.0   9381.182857
# 3                   4.0   2417.856822
# 4                   5.0   3396.525195
# 5                   6.0  32842.243988
# 6                   7.0  28528.247737
# 7                   8.0  16073.784182
# 8                   9.0  24389.908711
# 9                  10.0  55077.870453
# 10                 11.0  20021.764355

# %%
gdf.bos_district.value_counts()
# Out:
# 10    461
# 7     252
# 9     244
#       222
# 8     164
# 11    157
# 3     154
# 6     136
# 5      42
# 2      42
# 1      40
# 4      24
# Name: bos_district, dtype: int64

# %%
gdf.supervisor_district.value_counts()
# Out:
# 10.0    493
# 7.0     251
# 9.0     241
# 6.0     223
# 11.0    167
# 8.0     164
# 3.0     155
# 2.0      58
# 5.0      42
# 1.0      40
# 4.0      23
# Name: supervisor_district, dtype: int64

# %%
blank_rows = gdf[gdf["bos_district"].apply(lambda x: isinstance(x, str) and x.strip() == '')]

blank_rows
# Out:
#            cnn    street_name  \
# 40    19002000       14TH AVE
# 59     1023000        20TH ST
# 60     1024000        20TH ST
# 143    2234000      ALVORD ST
# 144    2235000      ALVORD ST
# ...        ...            ...
# 1945  15329000  SUNNYDALE AVE
# 1946  15331000    SUNRISE WAY
# 1947  14348000       MACKY LN
# 1948  14291000     MAYBECK ST
# 1949  14276000    FARALLON ST
#
#                                                location      x_coord  \
# 40          14TH AVE: WEDEMEYER ST to PARK BLVD (0 - 0)  5991466.898
# 59     20TH ST: LOUISIANA ST to UNNAMED 042 (300 - 399)  6016741.428
# 60      20TH ST: UNNAMED 042 to MICHIGAN ST (400 - 499)  6016476.021
# 143               ALVORD ST: END to CARROLL AVE (0 - 0)  6019520.709
# 144        ALVORD ST: CARROLL AVE to DONNER AVE (0 - 0)  6019364.737
# ...                                                 ...          ...
# 1945            SUNNYDALE AVE: SANTOS ST to END (0 - 0)  6006743.014
# 1946        SUNRISE WAY: MALOSI ST to SANTOS ST (0 - 0)  6006690.422
# 1947           MACKY LN: GOLDEN BELL WAY to END (0 - 0)  6021870.888
# 1948  MAYBECK ST: AVENUE OF THE PALMS to GARDEN WALK...  6019867.686
# 1949       FARALLON ST: END to BRAGHETTA LN (248 - 299)  6021832.966
#
#           y_coord   latitude   longitude bos_district zip_code  \
# 40    2115162.931  37.787342 -122.473337                 94129
# 59    2104935.968  37.760693 -122.385179
# 60    2104921.431  37.760638 -122.386096
# 143   2088104.632  37.714630 -122.374401                 94124
# 144   2087895.556  37.714048 -122.374925                 94124
# ...           ...        ...         ...          ...      ...
# 1945  2087633.962  37.712627 -122.418532
# 1946  2086843.851  37.710454 -122.418658
# 1947  2127869.609  37.823946 -122.369023
# 1948  2128150.234  37.824606 -122.375976
# 1949  2126919.408  37.821335 -122.369088
#
#      sfar_neighborhood_desc          jurisdiction               layer  \
# 40                 Presidio  PRESIDIO/RECPARK/DPW  PARKS_NPS_PRESIDIO
# 59                                            DPW             STREETS
# 60                                            DPW             STREETS
# 143                     NaN                   DPW         PAPER_WATER
# 144                     NaN                   DPW         PAPER_WATER
# ...                     ...                   ...                 ...
# 1945                                          DPW               PAPER
# 1946                                          DPW               PAPER
# 1947                                          DPW             STREETS
# 1948                                          DPW             STREETS
# 1949                                          DPW             STREETS
#
#      bike_path accepted                                               line  \
# 40         Yes        N  LINESTRING (-122.47335421 37.787491818, -122.4...
# 59          No        N  LINESTRING (-122.38475499 37.760717793, -122.3...
# 60          No        N  LINESTRING (-122.385603281 37.760667282, -122....
# 143         No        N  LINESTRING (-122.374157371 37.714900715, -122....
# 144         No        N  LINESTRING (-122.374643932 37.714359953, -122....
# ...        ...      ...                                                ...
# 1945        No        N  LINESTRING (-122.418038222 37.712487948, -122....
# 1946        No        N  LINESTRING (-122.418243703 37.710337536, -122....
# 1947        No        N  LINESTRING (-122.368222763 37.822730801, -122....
# 1948        No        N  LINESTRING (-122.376249932 37.824351379, -122....
# 1949        No        N  LINESTRING (-122.369332765 37.821233243, -122....
#
#      active  supervisor_district  \
# 40     True                  2.0
# 59     True                 10.0
# 60     True                 10.0
# 143    True                  NaN
# 144    True                  NaN
# ...     ...                  ...
# 1945   True                 10.0
# 1946   True                 10.0
# 1947   True                  6.0
# 1948   True                  6.0
# 1949   True                  6.0
#
#                                                geometry    length_m
# 40    LINESTRING (546371.367 4182367.808, 546374.507...   33.278919
# 59    LINESTRING (554192.173 4179444.880, 554117.489...   74.931624
# 60    LINESTRING (554117.489 4179438.785, 554030.721...   87.056265
# 143   LINESTRING (555159.630 4174367.721, 555117.146...   73.748999
# 144   LINESTRING (555117.146 4174307.438, 555068.014...   85.215571
# ...                                                 ...         ...
# 1945  LINESTRING (551293.750 4174075.092, 551206.459...   92.396144
# 1946  LINESTRING (551277.121 4173836.395, 551203.908...   77.521950
# 1947  LINESTRING (555601.891 4186334.918, 555459.263...  304.158021
# 1948  LINESTRING (554894.223 4186509.975, 554942.000...   74.272944
# 1949  LINESTRING (555505.321 4186168.103, 555548.203...   48.561061
#
# [222 rows x 19 columns]

# %% [markdown]
# ### calculating the area of each district

# %% [markdown]
# Below I'm reading in a supervisor district dataset to compare street segments with area. I'm running the same kind of reprojections to calculate the area of each district in square miles.

# %% [markdown]
# This file was obtained from [S.F. Open Data](https://data.sfgov.org/Geographic-Locations-and-Boundaries/Supervisor-Districts-2022-/f2zs-jevy/about_data)

# %%
gdf_supe = gpd.read_file('./data/supe22.geojson')

# %%
gdf_supe
# Out:
#    sup_dist_pad sup_dist_num              sup_dist_name      data_loaded_at  \
# 0            01          1.0   SUPERVISORIAL DISTRICT 1 2025-01-08 18:30:00
# 1            02          2.0   SUPERVISORIAL DISTRICT 2 2025-01-08 18:30:00
# 2            03          3.0   SUPERVISORIAL DISTRICT 3 2025-01-08 18:30:00
# 3            04          4.0   SUPERVISORIAL DISTRICT 4 2025-01-08 18:30:00
# 4            05          5.0   SUPERVISORIAL DISTRICT 5 2025-01-08 18:30:00
# 5            06          6.0   SUPERVISORIAL DISTRICT 6 2025-01-08 18:30:00
# 6            07          7.0   SUPERVISORIAL DISTRICT 7 2025-01-08 18:30:00
# 7            08          8.0   SUPERVISORIAL DISTRICT 8 2025-01-08 18:30:00
# 8            09          9.0   SUPERVISORIAL DISTRICT 9 2025-01-08 18:30:00
# 9            10         10.0  SUPERVISORIAL DISTRICT 10 2025-01-08 18:30:00
# 10           11         11.0  SUPERVISORIAL DISTRICT 11 2025-01-08 18:30:00
#
#             sup_name sup_dist          data_as_of  \
# 0        Connie Chan        1 2025-01-08 18:30:00
# 1   Stephen Sherrill        2 2025-01-08 18:30:00
# 2       Danny Sauter        3 2025-01-08 18:30:00
# 3      Joel Engardio        4 2025-01-08 18:30:00
# 4      Bilal Mahmood        5 2025-01-08 18:30:00
# 5        Matt Dorsey        6 2025-01-08 18:30:00
# 6       Myrna Melgar        7 2025-01-08 18:30:00
# 7   Rafael Mandelman        8 2025-01-08 18:30:00
# 8     Jackie Fielder        9 2025-01-08 18:30:00
# 9     Shamann Walton       10 2025-01-08 18:30:00
# 10      Chyanne Chen       11 2025-01-08 18:30:00
#
#                                              geometry
# 0   MULTIPOLYGON (((-122.48520 37.79020, -122.4848...
# 1   MULTIPOLYGON (((-122.47695 37.81098, -122.4766...
# 2   MULTIPOLYGON (((-122.41972 37.81113, -122.4195...
# 3   MULTIPOLYGON (((-122.51103 37.77056, -122.5110...
# 4   MULTIPOLYGON (((-122.42706 37.78879, -122.4254...
# 5   MULTIPOLYGON (((-122.33154 37.78694, -122.3279...
# 6   MULTIPOLYGON (((-122.46583 37.77261, -122.4654...
# 7   MULTIPOLYGON (((-122.42371 37.77270, -122.4236...
# 8   MULTIPOLYGON (((-122.42225 37.77052, -122.4217...
# 9   MULTIPOLYGON (((-122.38541 37.76725, -122.3858...
# 10  MULTIPOLYGON (((-122.43015 37.73234, -122.4295...

# %%
print(gdf_supe.crs)
# Out:
# epsg:4326

# %%
gdf_supe = gdf_supe.set_crs("EPSG:4326", allow_override=True)

gdf_supe = gdf_supe.to_crs("EPSG:32610")

gdf_supe["area_sqm"] = gdf_supe.geometry.area
gdf_supe["area_sqmi"] = gdf_supe["area_sqm"] / 2.59e+6

# %%
gdf_supe
# Out:
#    sup_dist_pad sup_dist_num              sup_dist_name      data_loaded_at  \
# 0            01          1.0   SUPERVISORIAL DISTRICT 1 2025-01-08 18:30:00
# 1            02          2.0   SUPERVISORIAL DISTRICT 2 2025-01-08 18:30:00
# 2            03          3.0   SUPERVISORIAL DISTRICT 3 2025-01-08 18:30:00
# 3            04          4.0   SUPERVISORIAL DISTRICT 4 2025-01-08 18:30:00
# 4            05          5.0   SUPERVISORIAL DISTRICT 5 2025-01-08 18:30:00
# 5            06          6.0   SUPERVISORIAL DISTRICT 6 2025-01-08 18:30:00
# 6            07          7.0   SUPERVISORIAL DISTRICT 7 2025-01-08 18:30:00
# 7            08          8.0   SUPERVISORIAL DISTRICT 8 2025-01-08 18:30:00
# 8            09          9.0   SUPERVISORIAL DISTRICT 9 2025-01-08 18:30:00
# 9            10         10.0  SUPERVISORIAL DISTRICT 10 2025-01-08 18:30:00
# 10           11         11.0  SUPERVISORIAL DISTRICT 11 2025-01-08 18:30:00
#
#             sup_name sup_dist          data_as_of  \
# 0        Connie Chan        1 2025-01-08 18:30:00
# 1   Stephen Sherrill        2 2025-01-08 18:30:00
# 2       Danny Sauter        3 2025-01-08 18:30:00
# 3      Joel Engardio        4 2025-01-08 18:30:00
# 4      Bilal Mahmood        5 2025-01-08 18:30:00
# 5        Matt Dorsey        6 2025-01-08 18:30:00
# 6       Myrna Melgar        7 2025-01-08 18:30:00
# 7   Rafael Mandelman        8 2025-01-08 18:30:00
# 8     Jackie Fielder        9 2025-01-08 18:30:00
# 9     Shamann Walton       10 2025-01-08 18:30:00
# 10      Chyanne Chen       11 2025-01-08 18:30:00
#
#                                              geometry      area_sqm  \
# 0   MULTIPOLYGON (((545326.945 4182662.139, 545358...  1.008838e+07
# 1   MULTIPOLYGON (((546039.995 4184972.363, 546069...  1.315037e+07
# 2   MULTIPOLYGON (((551077.283 4185018.963, 551090...  5.375721e+06
# 3   MULTIPOLYGON (((543063.801 4180470.892, 543065...  2.605506e+08
# 4   MULTIPOLYGON (((550446.742 4182535.475, 550590...  4.602155e+06
# 5   MULTIPOLYGON (((558859.079 4182386.607, 559182...  9.189229e+06
# 6   MULTIPOLYGON (((547043.753 4180720.333, 547075...  2.093441e+07
# 7   MULTIPOLYGON (((550752.354 4180752.555, 550755...  9.351741e+06
# 8   MULTIPOLYGON (((550883.135 4180511.261, 550928...  8.558112e+06
# 9   MULTIPOLYGON (((554129.384 4180169.082, 554093...  1.943980e+07
# 10  MULTIPOLYGON (((550212.902 4176270.967, 550263...  8.797882e+06
#
#      area_sqmi
# 0     3.895126
# 1     5.077364
# 2     2.075568
# 3   100.598706
# 4     1.776894
# 5     3.547965
# 6     8.082782
# 7     3.610711
# 8     3.304290
# 9     7.505714
# 10    3.396866

# %%
gdf_supe = gdf_supe[['sup_dist_num', 'area_sqmi', 'area_sqm']]

# %%
gdf_supe.dtypes
# Out:
# sup_dist_num     object
# area_sqmi       float64
# area_sqm        float64
# dtype: object

# %%
gdf_supe['sup_dist_num'] = gdf_supe['sup_dist_num'].astype(float)
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_10698/4159580652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_supe['sup_dist_num'] = gdf_supe['sup_dist_num'].astype(float)

# %% [markdown]
# ### stats

# %% [markdown]
# This is the total length of all the unaccepted streets in each district:

# %%
total_length_by_district_2.sort_values(by='length_m', ascending=False, inplace=True)

total_length_by_district_2
# Out:
#     supervisor_district      length_m
# 9                  10.0  55077.870453
# 5                   6.0  32842.243988
# 6                   7.0  28528.247737
# 8                   9.0  24389.908711
# 10                 11.0  20021.764355
# 7                   8.0  16073.784182
# 1                   2.0  10848.119709
# 2                   3.0   9381.182857
# 0                   1.0   6795.323660
# 4                   5.0   3396.525195
# 3                   4.0   2417.856822

# %% [markdown]
# This shows the same thing with the percentage of unaccepted streets in each district, compared to the total length of all streets in the city:

# %%
total_length_by_district_2['percentage'] = (total_length_by_district_2['length_m'] / total_length_by_district_2['length_m'].sum()) * 100

total_length_by_district_2
# Out:
#     supervisor_district      length_m  percentage
# 9                  10.0  55077.870453   26.255960
# 5                   6.0  32842.243988   15.656100
# 6                   7.0  28528.247737   13.599592
# 8                   9.0  24389.908711   11.626820
# 10                 11.0  20021.764355    9.544498
# 7                   8.0  16073.784182    7.662472
# 1                   2.0  10848.119709    5.171366
# 2                   3.0   9381.182857    4.472068
# 0                   1.0   6795.323660    3.239373
# 4                   5.0   3396.525195    1.619144
# 3                   4.0   2417.856822    1.152607

# %% [markdown]
# The total length of unaccepted streets in the city, in meters:

# %%
total_length_by_district_2.length_m.sum()
# Out:
# 209772.82767035303

# %% [markdown]
# The same thing, in miles:

# %%
total_length_by_district_2.length_m.sum() / 1609.34  # 1 mile = 1609.34 meters
# Out:
# 130.34711600429557

# %%
total_length_by_district_2['length_mi'] = total_length_by_district_2['length_m'] / 1609.34  # Convert meters to miles

# %% [markdown]
# Here I'm adding the area data to the district totals:

# %%
merged_gdf = total_length_by_district_2.merge(gdf_supe, left_on='supervisor_district', right_on='sup_dist_num', how='left')

# %%
merged_gdf
# Out:
#     supervisor_district      length_m  percentage  length_mi  sup_dist_num  \
# 0                  10.0  55077.870453   26.255960  34.223887          10.0
# 1                   6.0  32842.243988   15.656100  20.407275           6.0
# 2                   7.0  28528.247737   13.599592  17.726675           7.0
# 3                   9.0  24389.908711   11.626820  15.155224           9.0
# 4                  11.0  20021.764355    9.544498  12.440979          11.0
# 5                   8.0  16073.784182    7.662472   9.987811           8.0
# 6                   2.0  10848.119709    5.171366   6.740726           2.0
# 7                   3.0   9381.182857    4.472068   5.829211           3.0
# 8                   1.0   6795.323660    3.239373   4.222429           1.0
# 9                   5.0   3396.525195    1.619144   2.110508           5.0
# 10                  4.0   2417.856822    1.152607   1.502390           4.0
#
#      area_sqmi      area_sqm
# 0     7.505714  1.943980e+07
# 1     3.547965  9.189229e+06
# 2     8.082782  2.093441e+07
# 3     3.304290  8.558112e+06
# 4     3.396866  8.797882e+06
# 5     3.610711  9.351741e+06
# 6     5.077364  1.315037e+07
# 7     2.075568  5.375721e+06
# 8     3.895126  1.008838e+07
# 9     1.776894  4.602155e+06
# 10  100.598706  2.605506e+08

# %% [markdown]
# For every square mile, this is how many miles of unaccepted streets there are in each district:

# %%
merged_gdf['length_per_sqmi'] = merged_gdf['length_mi'] / merged_gdf['area_sqmi']

# %%
merged_gdf.sort_values(by='length_per_sqmi', ascending=False, inplace=True)

merged_gdf
# Out:
#     supervisor_district      length_m  percentage  length_mi  sup_dist_num  \
# 1                   6.0  32842.243988   15.656100  20.407275           6.0
# 3                   9.0  24389.908711   11.626820  15.155224           9.0
# 0                  10.0  55077.870453   26.255960  34.223887          10.0
# 4                  11.0  20021.764355    9.544498  12.440979          11.0
# 7                   3.0   9381.182857    4.472068   5.829211           3.0
# 5                   8.0  16073.784182    7.662472   9.987811           8.0
# 2                   7.0  28528.247737   13.599592  17.726675           7.0
# 6                   2.0  10848.119709    5.171366   6.740726           2.0
# 9                   5.0   3396.525195    1.619144   2.110508           5.0
# 8                   1.0   6795.323660    3.239373   4.222429           1.0
# 10                  4.0   2417.856822    1.152607   1.502390           4.0
#
#      area_sqmi      area_sqm  length_per_sqmi
# 1     3.547965  9.189229e+06         5.751826
# 3     3.304290  8.558112e+06         4.586530
# 0     7.505714  1.943980e+07         4.559711
# 4     3.396866  8.797882e+06         3.662487
# 7     2.075568  5.375721e+06         2.808490
# 5     3.610711  9.351741e+06         2.766162
# 2     8.082782  2.093441e+07         2.193140
# 6     5.077364  1.315037e+07         1.327603
# 9     1.776894  4.602155e+06         1.187751
# 8     3.895126  1.008838e+07         1.084029
# 10  100.598706  2.605506e+08         0.014934

# %% [markdown]
# Dropping a column that is not needed anymore:

# %%
merged_gdf = merged_gdf.drop(columns=['sup_dist_num'])

# %%
merged_gdf
# Out:
#     supervisor_district      length_m  percentage  length_mi   area_sqmi  \
# 1                   6.0  32842.243988   15.656100  20.407275    3.547965
# 3                   9.0  24389.908711   11.626820  15.155224    3.304290
# 0                  10.0  55077.870453   26.255960  34.223887    7.505714
# 4                  11.0  20021.764355    9.544498  12.440979    3.396866
# 7                   3.0   9381.182857    4.472068   5.829211    2.075568
# 5                   8.0  16073.784182    7.662472   9.987811    3.610711
# 2                   7.0  28528.247737   13.599592  17.726675    8.082782
# 6                   2.0  10848.119709    5.171366   6.740726    5.077364
# 9                   5.0   3396.525195    1.619144   2.110508    1.776894
# 8                   1.0   6795.323660    3.239373   4.222429    3.895126
# 10                  4.0   2417.856822    1.152607   1.502390  100.598706
#
#         area_sqm  length_per_sqmi
# 1   9.189229e+06         5.751826
# 3   8.558112e+06         4.586530
# 0   1.943980e+07         4.559711
# 4   8.797882e+06         3.662487
# 7   5.375721e+06         2.808490
# 5   9.351741e+06         2.766162
# 2   2.093441e+07         2.193140
# 6   1.315037e+07         1.327603
# 9   4.602155e+06         1.187751
# 8   1.008838e+07         1.084029
# 10  2.605506e+08         0.014934

# %% [markdown]
# ### total streets

# %% [markdown]
# Going back to our streets dataset with **all** streets in San Francisco, so that we can compare unaccepted streets with all streets.

# %% [markdown]
# Making the same adjustments to this dataset as the other ones so that we can obtain correct measurements in meters, and covert to miles. I am also filtering the streets data to only include "active" streets (the dataset includes retired streets as well)

# %%
gdf_streets = gpd.GeoDataFrame(df_streets, geometry=gpd.GeoSeries.from_wkt(df_streets['line']))

gdf_streets = gdf_streets[gdf_streets['active'] == True]

gdf_streets = gdf_streets.set_crs("EPSG:4326", allow_override=True)

gdf_streets = gdf_streets.to_crs("EPSG:32610")

gdf_streets["length_m"] = gdf_streets.geometry.length

gdf_streets["length_mi"] = gdf_streets["length_m"] / 1609.34  # Convert meters to miles

# %%
gdf_streets.active.value_counts()
# Out:
# True    16367
# Name: active, dtype: int64

# %%
total_length_all_streets_by_district = gdf_streets.groupby('supervisor_district')['length_mi'].sum().reset_index()

# %% [markdown]
# This is the total length of all streets in each district:

# %%
total_length_all_streets_by_district
# Out:
#     supervisor_district   length_mi
# 0                   1.0   85.917765
# 1                   2.0  121.167011
# 2                   3.0   71.081974
# 3                   4.0  118.869783
# 4                   5.0   54.044416
# 5                   6.0  114.159281
# 6                   7.0  178.138472
# 7                   8.0  111.248616
# 8                   9.0  110.720127
# 9                  10.0  163.929841
# 10                 11.0  112.281881

# %% [markdown]
# This will join the summary table to our big summary table:

# %%
merged_gdf = merged_gdf.merge(total_length_all_streets_by_district, on='supervisor_district', how='left', suffixes=('', '_streets'))

# %% [markdown]
# This calcualtes the percentage of unaccepted streets compared to all streets in each district:

# %%
merged_gdf['percentage_length'] = (merged_gdf['length_mi'] / merged_gdf['length_mi_streets']) * 100

# %%
merged_gdf
# Out:
#     supervisor_district      length_m  percentage  length_mi   area_sqmi  \
# 0                   6.0  32842.243988   15.656100  20.407275    3.547965
# 1                   9.0  24389.908711   11.626820  15.155224    3.304290
# 2                  10.0  55077.870453   26.255960  34.223887    7.505714
# 3                  11.0  20021.764355    9.544498  12.440979    3.396866
# 4                   3.0   9381.182857    4.472068   5.829211    2.075568
# 5                   8.0  16073.784182    7.662472   9.987811    3.610711
# 6                   7.0  28528.247737   13.599592  17.726675    8.082782
# 7                   2.0  10848.119709    5.171366   6.740726    5.077364
# 8                   5.0   3396.525195    1.619144   2.110508    1.776894
# 9                   1.0   6795.323660    3.239373   4.222429    3.895126
# 10                  4.0   2417.856822    1.152607   1.502390  100.598706
#
#         area_sqm  length_per_sqmi  length_mi_streets  percentage_length
# 0   9.189229e+06         5.751826         114.159281          17.876142
# 1   8.558112e+06         4.586530         110.720127          13.687868
# 2   1.943980e+07         4.559711         163.929841          20.877155
# 3   8.797882e+06         3.662487         112.281881          11.080130
# 4   5.375721e+06         2.808490          71.081974           8.200688
# 5   9.351741e+06         2.766162         111.248616           8.977920
# 6   2.093441e+07         2.193140         178.138472           9.951065
# 7   1.315037e+07         1.327603         121.167011           5.563169
# 8   4.602155e+06         1.187751          54.044416           3.905136
# 9   1.008838e+07         1.084029          85.917765           4.914500
# 10  2.605506e+08         0.014934         118.869783           1.263896

# %%
length_overview = merged_gdf[['supervisor_district', 'length_mi', 'length_mi_streets', 'percentage_length']]

# %%
length_overview = length_overview.round(1)
length_overview
# Out:
#     supervisor_district  length_mi  length_mi_streets  percentage_length
# 0                   6.0       20.4              114.2               17.9
# 1                   9.0       15.2              110.7               13.7
# 2                  10.0       34.2              163.9               20.9
# 3                  11.0       12.4              112.3               11.1
# 4                   3.0        5.8               71.1                8.2
# 5                   8.0       10.0              111.2                9.0
# 6                   7.0       17.7              178.1               10.0
# 7                   2.0        6.7              121.2                5.6
# 8                   5.0        2.1               54.0                3.9
# 9                   1.0        4.2               85.9                4.9
# 10                  4.0        1.5              118.9                1.3

# %% [markdown]
# ### exports

# %% [markdown]
# Exporting a more readable version of the summary table to a CSV file:

# %%
length_overview.to_csv('./output/length_overview.csv', index=False)

# %% [markdown]
# Exporting the rows that don't fall into any district to a CSV file (to look at in QGIS):

# %%
blank_rows.to_file('./output/no_district.geojson', driver='GeoJSON')

# %% [markdown]
# Exporting our main geoDataFrame with all the unaccepted streets to a geojson file, for mapping:

# %%
gdf.to_file('./output.output.geojson', driver='GeoJSON')
